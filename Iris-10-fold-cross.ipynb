# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt("cancer-results.txt")

# %%
## Nrows is the number of samples
## Ncolumns is the number of clusters (1 to N)
np.shape(data)
# Out:
# (100, 140)

# %%
## Calculate the mean -percentage- corre
## We used 10-fold random subsampling validation (10.0)
## Apply the np.mean() function across the rows (axis 0, one mean per column)
means = np.apply_along_axis(np.mean,0,data)*100.0/10.0
means
# Out:
# array([13.5, 18.1, 24. , 24.5, 35.2, 33.5, 38.1, 42.2, 44.8, 43.7, 47.3,
#        48.2, 47.2, 44.5, 44.6, 47.5, 50.7, 50.5, 50.2, 49.4, 49.2, 47.2,
#        48. , 53. , 49.5, 50.7, 50.2, 50.7, 51.1, 51. , 54. , 52.8, 51.3,
#        52.2, 50.6, 53.1, 50.7, 51.6, 50.8, 53.5, 53.2, 52.7, 54.2, 52.1,
#        53.6, 52.9, 52.1, 51.3, 54.1, 54.4, 50.6, 52.1, 52.7, 56.5, 53.4,
#        52. , 54.5, 53.8, 55.4, 52.4, 52.8, 52.1, 52.7, 52.9, 52.8, 53.1,
#        52.1, 52.8, 53.3, 54.9, 54.6, 54.7, 53.2, 51.2, 52.4, 56. , 53.9,
#        50.1, 54.3, 51.9, 55.5, 53.8, 52.6, 52.9, 54.2, 56.6, 56.1, 54.7,
#        53.8, 53.6, 54.6, 55.4, 54.8, 55.9, 55.4, 79.6, 92.6, 91.1, 92.9,
#        86.2, 83.8, 93. , 93.1, 90.9, 92.6, 93.7, 92.8, 91.5, 83.8, 90.8,
#        87.6, 90.4, 86.5, 93.7, 95. , 89. , 93.6, 88.4, 96.3, 84.5, 94.7,
#        91. , 96.7, 96.8, 95.9, 96.1, 90.8, 96.1, 98.6, 86. , 91. , 92.2,
#        89.5, 97. , 99.8, 99.2, 97.5, 91.3, 97.5, 91.8])

# %%
## Standard error is the standard deviation (np.std) / sqrt(N-1)
## Alternatively, we just use scipy.stats.sem() [sps.sem()]
stderr = np.apply_along_axis(np.std,0,data)*100.0/(10.0*np.sqrt(np.shape(data)[0]-1))
stderr = np.apply_along_axis(sps.sem,0,data)*100.0/10.0
stderr
# Out:
# array([0.88048426, 1.13435783, 1.35587014, 1.26630776, 1.38884444,
#        1.37344954, 1.64957907, 1.45352237, 1.37422154, 1.42598539,
#        1.41317752, 1.62915359, 1.44306072, 1.45903663, 1.46625339,
#        1.45903663, 1.46511626, 1.53987406, 1.67561236, 1.63805748,
#        1.57428836, 1.53793775, 1.75809815, 1.67874412, 1.27425954,
#        1.3276774 , 1.44934677, 1.31237313, 1.55631655, 1.71446608,
#        1.6017667 , 1.34899888, 1.33828626, 1.49463688, 1.54932374,
#        1.70379849, 1.51927016, 1.58094717, 1.54187345, 1.67799183,
#        1.51677489, 1.38429138, 1.37201467, 1.41631903, 1.55388077,
#        1.5846167 , 1.43051167, 1.72125747, 1.32645955, 1.39494035,
#        1.42005833, 1.43051167, 1.42030727, 1.59148619, 1.48541733,
#        1.53082799, 1.43811746, 1.48922053, 1.55972025, 1.45032215,
#        1.50473999, 1.3654836 , 1.61342224, 1.61617456, 1.45004354,
#        1.44735914, 1.45154046, 1.54449168, 1.42172892, 1.39620698,
#        1.39566428, 1.42456798, 1.4625286 , 1.65925625, 1.58350079,
#        1.51757382, 1.55631655, 1.40342294, 1.45820562, 1.4750107 ,
#        1.43811746, 1.45491157, 1.48133164, 1.64098394, 1.65254624,
#        1.45796316, 1.48320565, 1.50725518, 1.56850311, 1.56036774,
#        1.500303  , 1.58541331, 1.6110728 , 1.49811329, 1.34404786,
#        0.87524888, 0.71942738, 0.75068992, 0.74257265, 0.89645768,
#        0.89645768, 0.6435382 , 0.77453146, 0.79257922, 0.52454887,
#        0.71991863, 0.62084986, 0.7703469 , 1.01284677, 0.8       ,
#        0.84231523, 0.80302459, 0.94681817, 0.69128778, 0.70352647,
#        0.82265891, 0.68931235, 0.83750471, 0.54411452, 1.01876336,
#        0.61059666, 0.89329715, 0.51355367, 0.51010001, 0.53361735,
#        0.52981796, 0.87247471, 0.49020713, 0.34873509, 0.81649658,
#        0.73167857, 0.73278216, 0.88048426, 0.50251891, 0.14070529,
#        0.27265992, 0.5       , 0.71991863, 0.5       , 0.80879009])

# %%
## Make the plot bigger to get a better resolution
plt.figure(figsize=(15,5));
## Use an error bar plot...
plt.errorbar(np.array(range(len(means)))+1.0,means,yerr=stderr);
## Fix the axis labels
plt.xlabel('Number of Clusters (K)');
plt.ylabel('Percentage Correct (%) [+- Std. Err.]');
