# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt("iris-results.txt")

# %%
## Nrows is the number of samples
## Ncolumns is the number of clusters (1 to N)
np.shape(data)
# Out:
# (100, 140)

# %%
## Calculate the mean -percentage- corre
## We used 10-fold random subsampling validation (10.0)
## Apply the np.mean() function across the rows (axis 0, one mean per column)
means = np.apply_along_axis(np.mean,0,data)*100.0/10.0
means
# Out:
# array([34. , 68.3, 83. , 87.7, 88.4, 92.2, 91.4, 92.9, 94.5, 94.4, 94.9,
#        96.7, 96.2, 96. , 96.6, 96.3, 97.5, 97.4, 96.1, 94.9, 97.6, 97.5,
#        97.1, 97.4, 97.2, 96. , 97.4, 96.3, 95.9, 95.4, 95.8, 96.6, 97.1,
#        96.4, 95.3, 95.9, 94.8, 94.8, 95.6, 96.4, 94.7, 95.6, 95.2, 96.3,
#        95.8, 94.6, 94.4, 96.4, 96.4, 96.3, 94.5, 95.6, 96.2, 94.7, 94.7,
#        96. , 96.3, 94.9, 96.2, 94.9, 95.5, 95.8, 96.3, 95.6, 95.3, 97.2,
#        96.7, 95.9, 95.1, 96.1, 94.5, 94.9, 96.6, 96.1, 95.9, 94.2, 95.2,
#        94.7, 95.8, 95.2, 95.2, 95.4, 96.1, 96. , 95.7, 95.7, 93.6, 95.2,
#        95.4, 95. , 96. , 95.9, 94.1, 94.8, 94.9, 95.5, 95.8, 95.4, 96. ,
#        94.3, 95.5, 96.1, 96.4, 96.7, 93.4, 95.2, 95.9, 95. , 96.6, 95.1,
#        96. , 96. , 94.9, 95.3, 96.8, 94.8, 95.2, 95.7, 95.8, 96.5, 94.6,
#        95. , 97.2, 95.7, 96.5, 95.2, 95. , 94.8, 95.2, 95. , 95.3, 94.8,
#        95.9, 95.5, 95.8, 96.5, 96.1, 95.7, 95.9, 94.7])

# %%
## Standard error is the standard deviation (np.std) / sqrt(N-1)
## Alternatively, we just use scipy.stats.sem() [sps.sem()]
stderr = np.apply_along_axis(np.std,0,data)*100.0/(10.0*np.sqrt(np.shape(data)[0]-1))
stderr = np.apply_along_axis(sps.sem,0,data)*100.0/10.0
stderr
# Out:
# array([1.38534902, 1.55735466, 1.41778031, 0.98324345, 1.03201284,
#        0.91651514, 0.93225045, 0.92436164, 0.7703469 , 0.72918939,
#        0.71767019, 0.58697994, 0.56461303, 0.61954692, 0.55450406,
#        0.59721576, 0.47937249, 0.48450746, 0.58422011, 0.68894591,
#        0.47396884, 0.53889149, 0.5558686 , 0.52454887, 0.53333333,
#        0.55048188, 0.46319052, 0.56237232, 0.62109385, 0.64228129,
#        0.6060303 , 0.60669664, 0.47768381, 0.55994228, 0.64283149,
#        0.66810451, 0.71745904, 0.68872595, 0.60835928, 0.611671  ,
#        0.71710698, 0.67149765, 0.67390015, 0.61389632, 0.65412444,
#        0.70237692, 0.68637534, 0.55994228, 0.55994228, 0.66141874,
#        0.74366007, 0.67149765, 0.58222839, 0.74474591, 0.62692129,
#        0.58603272, 0.59721576, 0.73160954, 0.61594962, 0.62756544,
#        0.62563099, 0.6060303 , 0.58005573, 0.67149765, 0.70288008,
#        0.53333333, 0.55149018, 0.58766788, 0.62756544, 0.58422011,
#        0.68718427, 0.70345468, 0.60669664, 0.54855181, 0.66810451,
#        0.79366176, 0.67390015, 0.71710698, 0.55377492, 0.62732396,
#        0.62732396, 0.67300022, 0.69478577, 0.61954692, 0.5904116 ,
#        0.63968111, 0.81053667, 0.6432242 , 0.67300022, 0.67419986,
#        0.60302269, 0.57022058, 0.817671  , 0.71745904, 0.64345971,
#        0.70172947, 0.57172431, 0.59322777, 0.71066905, 0.72828843,
#        0.64157319, 0.6012613 , 0.65935383, 0.56951158, 0.72780284,
#        0.65874076, 0.58766788, 0.65904737, 0.60669664, 0.68894591,
#        0.65133895, 0.60302269, 0.65897073, 0.65835731, 0.63373193,
#        0.62732396, 0.70323926, 0.5904116 , 0.57172431, 0.62563099,
#        0.65782009, 0.73167857, 0.49400446, 0.57304785, 0.6092718 ,
#        0.7450849 , 0.70352647, 0.62732396, 0.61101009, 0.62764591,
#        0.62692129, 0.70323926, 0.51433982, 0.65712874, 0.65412444,
#        0.55732043, 0.63397097, 0.5904116 , 0.57022058, 0.74474591])

# %%
## Make the plot bigger to get a better resolution
plt.figure(figsize=(15,5));
## Use an error bar plot...
plt.errorbar(np.array(range(len(means)))+1.0,means,yerr=stderr);
## Fix the axis labels
plt.xlabel('Iris - Number of Clusters (K)');
plt.ylabel('Percentage Correct (%) [+- Std. Err.]');
