# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt("n-iris-results.txt")

# %%
## Nrows is the number of samples
## Ncolumns is the number of clusters (1 to N)
np.shape(data)
# Out:
# (100, 140)

# %%
## Calculate the mean -percentage- corre
## We used 10-fold random subsampling validation (10.0)
## Apply the np.mean() function across the rows (axis 0, one mean per column)
means = np.apply_along_axis(np.mean,0,data)*100.0/10.0
means
# Out:
# array([20.5, 59.7, 84.8, 86.6, 89.1, 90.5, 92.9, 91.8, 94.3, 93.3, 95.7,
#        95.7, 96. , 95.8, 95.5, 94.5, 94.9, 95.2, 96.4, 96.5, 96.2, 96.3,
#        97. , 94.8, 97. , 95.3, 96.4, 95.7, 95.2, 94.9, 95.1, 95.9, 94.9,
#        95.1, 96.7, 95.6, 96.5, 96.6, 95.4, 95.1, 95.8, 95.5, 96.8, 96.2,
#        95.4, 96.7, 95.9, 95.7, 94.8, 95.3, 95.9, 95.9, 96.3, 94.5, 96.4,
#        96.2, 95.7, 94.9, 95.2, 96.3, 95.3, 96.4, 95.3, 95.7, 95.5, 95.8,
#        96.4, 96.9, 94.7, 94.8, 94.2, 96.1, 95.4, 95.2, 95.6, 95.3, 96.9,
#        96.1, 94. , 96.1, 95.4, 94.3, 95. , 95.9, 96.2, 94.9, 96.8, 94.9,
#        94.7, 94.7, 95.6, 95.6, 95.1, 95.5, 94.7, 94.9, 95.7, 95.3, 95.8,
#        94.8, 95.3, 96.1, 95.5, 95.4, 95.8, 96. , 95. , 95.9, 94.8, 96.3,
#        93.3, 95.4, 95.9, 96. , 95.2, 95.3, 96.1, 95.8, 95.4, 96. , 95.6,
#        96.1, 94.8, 96.4, 94.9, 97.2, 95.1, 95.1, 95.9, 95.4, 95.8, 96.3,
#        96.1, 94.4, 95.2, 95.5, 95.1, 96.1, 94.6, 95.2])

# %%
## Standard error is the standard deviation (np.std) / sqrt(N-1)
## Alternatively, we just use scipy.stats.sem() [sps.sem()]
stderr = np.apply_along_axis(np.std,0,data)*100.0/(10.0*np.sqrt(np.shape(data)[0]-1))
stderr = np.apply_along_axis(sps.sem,0,data)*100.0/10.0
stderr.mean()
# Out:
# 0.6628293651860423

# %%
## Make the plot bigger to get a better resolution
plt.figure(figsize=(15,5));
## Use an error bar plot...
plt.errorbar(np.array(range(len(means)))+1.0,means,yerr=stderr);
## Fix the axis labels
plt.xlabel('Iris - Number of Clusters (K)');
plt.ylabel('NORMALIZED - Percentage Correct (%) [+- Std. Err.]');
